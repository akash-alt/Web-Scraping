# %%
base_url = "https://api.exchangeratesapi.io/latest"

# %%
import requests

# %%
response = requests.get(base_url)

# %%
response.ok
# Out:
# True

# %%
response.text
# Out:
# '{"rates":{"CAD":1.5265,"HKD":8.4259,"ISK":155.9,"PHP":54.939,"DKK":7.4657,"HUF":354.76,"CZK":26.909,"AUD":1.7444,"RON":4.833,"SEK":10.9455,"IDR":17243.21,"INR":82.9275,"BRL":5.5956,"RUB":80.69,"HRK":7.6175,"JPY":118.33,"THB":35.665,"CHF":1.0558,"SGD":1.5479,"PLN":4.5586,"BGN":1.9558,"TRY":7.3233,"CNY":7.6709,"NOK":11.2143,"NZD":1.8128,"ZAR":19.6383,"USD":1.0867,"MXN":26.0321,"ILS":3.8919,"GBP":0.87565,"KRW":1322.49,"MYR":4.7136},"base":"EUR","date":"2020-04-09"}'

# %%
response.content
# Out:
# b'{"rates":{"CAD":1.5265,"HKD":8.4259,"ISK":155.9,"PHP":54.939,"DKK":7.4657,"HUF":354.76,"CZK":26.909,"AUD":1.7444,"RON":4.833,"SEK":10.9455,"IDR":17243.21,"INR":82.9275,"BRL":5.5956,"RUB":80.69,"HRK":7.6175,"JPY":118.33,"THB":35.665,"CHF":1.0558,"SGD":1.5479,"PLN":4.5586,"BGN":1.9558,"TRY":7.3233,"CNY":7.6709,"NOK":11.2143,"NZD":1.8128,"ZAR":19.6383,"USD":1.0867,"MXN":26.0321,"ILS":3.8919,"GBP":0.87565,"KRW":1322.49,"MYR":4.7136},"base":"EUR","date":"2020-04-09"}'

# %%
response.json()
# Out:
# {'rates': {'CAD': 1.5265,
#   'HKD': 8.4259,
#   'ISK': 155.9,
#   'PHP': 54.939,
#   'DKK': 7.4657,
#   'HUF': 354.76,
#   'CZK': 26.909,
#   'AUD': 1.7444,
#   'RON': 4.833,
#   'SEK': 10.9455,
#   'IDR': 17243.21,
#   'INR': 82.9275,
#   'BRL': 5.5956,
#   'RUB': 80.69,
#   'HRK': 7.6175,
#   'JPY': 118.33,
#   'THB': 35.665,
#   'CHF': 1.0558,
#   'SGD': 1.5479,
#   'PLN': 4.5586,
#   'BGN': 1.9558,
#   'TRY': 7.3233,
#   'CNY': 7.6709,
#   'NOK': 11.2143,
#   'NZD': 1.8128,
#   'ZAR': 19.6383,
#   'USD': 1.0867,
#   'MXN': 26.0321,
#   'ILS': 3.8919,
#   'GBP': 0.87565,
#   'KRW': 1322.49,
#   'MYR': 4.7136},
#  'base': 'EUR',
#  'date': '2020-04-09'}

# %%
import json

# %%
json.dumps(response.json(),indent=5)
# Out:
# '{\n     "rates": {\n          "CAD": 1.5265,\n          "HKD": 8.4259,\n          "ISK": 155.9,\n          "PHP": 54.939,\n          "DKK": 7.4657,\n          "HUF": 354.76,\n          "CZK": 26.909,\n          "AUD": 1.7444,\n          "RON": 4.833,\n          "SEK": 10.9455,\n          "IDR": 17243.21,\n          "INR": 82.9275,\n          "BRL": 5.5956,\n          "RUB": 80.69,\n          "HRK": 7.6175,\n          "JPY": 118.33,\n          "THB": 35.665,\n          "CHF": 1.0558,\n          "SGD": 1.5479,\n          "PLN": 4.5586,\n          "BGN": 1.9558,\n          "TRY": 7.3233,\n          "CNY": 7.6709,\n          "NOK": 11.2143,\n          "NZD": 1.8128,\n          "ZAR": 19.6383,\n          "USD": 1.0867,\n          "MXN": 26.0321,\n          "ILS": 3.8919,\n          "GBP": 0.87565,\n          "KRW": 1322.49,\n          "MYR": 4.7136\n     },\n     "base": "EUR",\n     "date": "2020-04-09"\n}'

# %%
print(json.dumps(response.json(),indent=5))
# Out:
# {
#      "rates": {
#           "CAD": 1.5265,
#           "HKD": 8.4259,
#           "ISK": 155.9,
#           "PHP": 54.939,
#           "DKK": 7.4657,
#           "HUF": 354.76,
#           "CZK": 26.909,
#           "AUD": 1.7444,
#           "RON": 4.833,
#           "SEK": 10.9455,
#           "IDR": 17243.21,
#           "INR": 82.9275,
#           "BRL": 5.5956,
#           "RUB": 80.69,
#           "HRK": 7.6175,
#           "JPY": 118.33,
#           "THB": 35.665,
#           "CHF": 1.0558,
#           "SGD": 1.5479,
#           "PLN": 4.5586,
#           "BGN": 1.9558,
#           "TRY": 7.3233,
#           "CNY": 7.6709,
#           "NOK": 11.2143,
#           "NZD": 1.8128,
#           "ZAR": 19.6383,
#           "USD": 1.0867,
#           "MXN": 26.0321,
#           "ILS": 3.8919,
#           "GBP": 0.87565,
#           "KRW": 1322.49,
#           "MYR": 4.7136
#      },
#      "base": "EUR",
#      "date": "2020-04-09"
# }

# %%
response.json().keys()
# Out:
# dict_keys(['rates', 'base', 'date'])

# %% [markdown]
# # Obtaining historical exchange rate

# %%
base_url = ' https://api.exchangeratesapi.io'

# %%
historical_url = base_url + "/2016-01-12"
historical_url
# Out:
# ' https://api.exchangeratesapi.io/2016-01-12'

# %%
data= response.json()
print(json.dumps(data,indent = 4))
# Out:
# {
#     "rates": {
#         "CAD": 1.5265,
#         "HKD": 8.4259,
#         "ISK": 155.9,
#         "PHP": 54.939,
#         "DKK": 7.4657,
#         "HUF": 354.76,
#         "CZK": 26.909,
#         "AUD": 1.7444,
#         "RON": 4.833,
#         "SEK": 10.9455,
#         "IDR": 17243.21,
#         "INR": 82.9275,
#         "BRL": 5.5956,
#         "RUB": 80.69,
#         "HRK": 7.6175,
#         "JPY": 118.33,
#         "THB": 35.665,
#         "CHF": 1.0558,
#         "SGD": 1.5479,
#         "PLN": 4.5586,
#         "BGN": 1.9558,
#         "TRY": 7.3233,
#         "CNY": 7.6709,
#         "NOK": 11.2143,
#         "NZD": 1.8128,
#         "ZAR": 19.6383,
#         "USD": 1.0867,
#         "MXN": 26.0321,
#         "ILS": 3.8919,
#         "GBP": 0.87565,
#         "KRW": 1322.49,
#         "MYR": 4.7136
#     },
#     "base": "EUR",
#     "date": "2020-04-09"
# }

# %% [markdown]
# # Creating a simple currency convertor

# %%
date = input("Please enter the date(in the formet'yyyy-mm-dd' or 'latest'): ")
base = input("convert from (currency): ")
curr = input("convert to (currency): ")
quan = float(input("How much {} do you want to convert: ".format(base)))

url = base_url + "/" + date + "?base=" + base + "&symbols=" + curr
response = requests.get(url)

if(response.ok is False):
    print("\nError {}:".format(response.status_code))
    print(response.json()['error'])
    
else:
    data = response.json()
    rate = data['rates'][curr]
    
    result = quan*rate
    
    print("\n{0} {1} is equal to {2} {3}, based upon exchange rates on {4}".format(quan,base,result,curr,data['date']))
# Out:
# Please enter the date(in the formet'yyyy-mm-dd' or 'latest'): 2009-05-23
# convert from (currency): GBP
# convert to (currency): USD
# How much GBP do you want to convert: 39
#
# 39.0 GBP is equal to 62.0553467703 USD, based upon exchange rates on 2009-05-22

# %% [markdown]
# # iTunes search API

# %%
base_site = 'https://itunes.apple.com/search'

# %%
url = base_site + "?term=the+beatles&country=us"
requests.get(url)
# Out:
# <Response [200]>

# %%
r = requests.get(base_site,params = {"term":"the beatles","country":"us"})
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the+beatles&country=us'

# %% [markdown]
# # Investigeting the output patameters

# %%
info = r.json()
print(json.dumps(info,indent=4))
# Out:
# {
#     "resultCount": 50,
#     "results": [
#         {
#             "wrapperType": "track",
#             "kind": "song",
#             "artistId": 136975,
#             "collectionId": 1441164495,
#             "trackId": 1441164738,
#             "artistName": "The Beatles",
#             "collectionName": "Let It Be",
#             "trackName": "Let It Be",
#             "collectionCensoredName": "Let It Be",
#             "trackCensoredName": "Let It Be",
#             "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#             "collectionViewUrl": "https://music.apple.com/us/album/let-it-be/1441164495?i=1441164738&uo=4",
#             "trackViewUrl": "https://music.apple.com/us/album/let-it-be/1441164495?i=1441164738&uo=4",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/01/ff/05/01ff05d6-7892-4176-5efb-41a5438802d7/mzaf_8251314256578817405.plus.aac.p.m4a",
# ...

# %%
info.keys() # this is common format for search responses
# Out:
# dict_keys(['resultCount', 'results'])

# %%
print(json.dumps(info['results'][0],indent=4))# it is simple dict that is containing lot of data about musical track
# Out:
# {
#     "wrapperType": "track",
#     "kind": "song",
#     "artistId": 136975,
#     "collectionId": 1441164495,
#     "trackId": 1441164738,
#     "artistName": "The Beatles",
#     "collectionName": "Let It Be",
#     "trackName": "Let It Be",
#     "collectionCensoredName": "Let It Be",
#     "trackCensoredName": "Let It Be",
#     "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#     "collectionViewUrl": "https://music.apple.com/us/album/let-it-be/1441164495?i=1441164738&uo=4",
#     "trackViewUrl": "https://music.apple.com/us/album/let-it-be/1441164495?i=1441164738&uo=4",
#     "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/01/ff/05/01ff05d6-7892-4176-5efb-41a5438802d7/mzaf_8251314256578817405.plus.aac.p.m4a",
#     "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music118/v4/63/9b/2c/639b2caf-0186-39c3-b165-cac5eae1f38e/source/30x30bb.jpg",
# ...

# %%
info["resultCount"]# here i check about dictionary
# Out:
# 50

# %%
r = requests.get(base_site,params = {"term":"the beatles","country":"us","limit":200})
r.ok
# Out:
# True

# %%
r.json()["resultCount"]
# Out:
# 200

# %% [markdown]
# # Structure and exporting the data

# %%
info = r.json()
print(json.dumps(info,indent=4))

# %%
songs_df = pd.DataFrame(info["results"])
songs_df.head()
# Out:
#   wrapperType  kind  artistId  collectionId     trackId   artistName  \
# 0       track  song    136975    1441164495  1441164738  The Beatles
# 1       track  song    136975    1441133100  1441133277  The Beatles
# 2       track  song    136975    1474815798  1474815898  The Beatles
# 3       track  song    136975    1474815798  1474815799  The Beatles
# 4       track  song    136975    1441164359  1441164829  The Beatles
#
#                            collectionName           trackName  \
# 0                               Let It Be           Let It Be
# 1  The Beatles 1967-1970 (The Blue Album)            Hey Jude
# 2                   Abbey Road (2019 Mix)  Here Comes the Sun
# 3                   Abbey Road (2019 Mix)       Come Together
# 4                             Rubber Soul          In My Life
#
#                    collectionCensoredName              trackCensoredName  ...  \
# 0                               Let It Be                      Let It Be  ...
# ...

# %%
songs_df.to_csv("songs_df.csv")

# %%
songs_df.to_excel("songs_df.xlsx")

# %% [markdown]
# # Dealing with APIs which require registration

# %%
import requests
import json

# %%
APP_ID = "90cc30ba"
APP_KEYS = "56446de0e97451ed98c9007cfeece4f6"

# %%
api_endpoint = "https://developer.edamam.com/edamam-nutrition-api"

url = api_endpoint + "?app_id=" + APP_ID + "&app_keys=" + APP_KEYS

# %% [markdown]
# # Send post request

# %%
header = {
    "Content_Type" : "application/json"
}

# %%
recipe = {
    "title": "cappuccino",
    "ingr" :  "18g ground espresso,150ml milk"
     
}

# %%
r = requests.post(url, headers = header, json = recipe)
r.status_code
# Out:
# 404

# %% [markdown]
# # Inspecting tke response

# %%
from IPython.display import Image
Image(url='https://media.giphy.com/media/6w9mOk84lgdag/giphy.gif')
# Out:
# <img src="https://media.giphy.com/media/6w9mOk84lgdag/giphy.gif"/>
